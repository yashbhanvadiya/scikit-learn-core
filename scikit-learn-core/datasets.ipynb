# %%
from sklearn.datasets import load_breast_cancer, fetch_california_housing, make_blobs, make_moons
import matplotlib.pyplot as plt

# %%
df = load_breast_cancer(as_frame=True).frame
df
# Out:
#      mean radius  mean texture  ...  worst fractal dimension  target
# 0          17.99         10.38  ...                  0.11890       0
# 1          20.57         17.77  ...                  0.08902       0
# 2          19.69         21.25  ...                  0.08758       0
# 3          11.42         20.38  ...                  0.17300       0
# 4          20.29         14.34  ...                  0.07678       0
# ..           ...           ...  ...                      ...     ...
# 564        21.56         22.39  ...                  0.07115       0
# 565        20.13         28.25  ...                  0.06637       0
# 566        16.60         28.08  ...                  0.07820       0
# 567        20.60         29.33  ...                  0.12400       0
# 568         7.76         24.54  ...                  0.07039       1
#
# [569 rows x 31 columns]

# %%
df2 = fetch_california_housing(as_frame=True).frame
df2
# Out:
#        MedInc  HouseAge  AveRooms  ...  Latitude  Longitude  MedHouseVal
# 0      8.3252      41.0  6.984127  ...     37.88    -122.23        4.526
# 1      8.3014      21.0  6.238137  ...     37.86    -122.22        3.585
# 2      7.2574      52.0  8.288136  ...     37.85    -122.24        3.521
# 3      5.6431      52.0  5.817352  ...     37.85    -122.25        3.413
# 4      3.8462      52.0  6.281853  ...     37.85    -122.25        3.422
# ...       ...       ...       ...  ...       ...        ...          ...
# 20635  1.5603      25.0  5.045455  ...     39.48    -121.09        0.781
# 20636  2.5568      18.0  6.114035  ...     39.49    -121.21        0.771
# 20637  1.7000      17.0  5.205543  ...     39.43    -121.22        0.923
# 20638  1.8672      18.0  5.329513  ...     39.43    -121.32        0.847
# 20639  2.3886      16.0  5.254717  ...     39.37    -121.24        0.894
#
# [20640 rows x 9 columns]

# %%
df.hist(figsize=(15, 10))
plt.tight_layout()

# %%
x, y = make_blobs(n_samples=500, centers=5)
print(x)
print(y)
# Out:
# [[  4.97783441  -6.47076887]
#  [ -8.93735968   8.79650324]
#  [ -8.60276263  10.87983667]
#  [ -9.02762461   8.12574426]
#  [  6.30709395  -3.22386943]
#  [-10.73767517   5.95662851]
#  [-10.33994173   4.47528552]
#  [  8.44426516  -1.41089627]
#  [ -9.37450916   5.35062977]
#  [ -8.96165565  11.76135069]
#  [  5.47760344   0.15613829]
#  [ -9.05320055   2.92214297]
#  [ -9.43958039   5.39696579]
#  [-10.53278336   5.32339   ]
#  [  6.68976772  -2.11384908]
#  [ -9.68973776   9.04943776]
#  [ -9.71327727   2.6681473 ]
#  [ -8.48418945   9.09141754]
#  [ -9.63994733   6.14219628]
#  [ -9.04775545   4.26370067]
#  [ -8.88796036   3.20070051]
#  [ -7.51901983   3.94298085]
#  [  6.84488944  -0.22281916]
#  [-11.69625547   4.05316415]
#  [-10.57961023   6.65236855]
#  [  6.05096809  -8.63699662]
#  [ -9.17813241   3.4186477 ]
#  [ -9.88367213   4.08336508]
#  [  7.16390735  -8.2482877 ]
#  [  7.41495706  -7.41452135]
#  [ -7.90695465   4.26794404]
#  [ -9.33161272   1.37341427]
# ...

# %%
plt.scatter(x[:, 0], x[:, 1], c=y)

# %%
a, b = make_moons(noise=0.1, random_state=0)
plt.scatter(a[:, 0], a[:, 1], c=b)
