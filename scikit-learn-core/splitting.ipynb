# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split, StratifiedShuffleSplit
import numpy as np
import matplotlib.pyplot as plt

# %%
data = load_iris()
X = data.data
y = data.target

# %%
X_train, X_testing, y_train, y_testing = train_test_split(X, y, test_size=0.2) ## 20% testing, 80% training
len(X_testing)
# Out:
# 30

# %%
counts = np.bincount(y_train)
positions = np.arange(3)

plt.bar(positions, counts)
plt.xticks(positions, data.target_names)
# Out:
# ([<matplotlib.axis.XTick at 0x1363dab9e50>,
# ...
#  [Text(0, 0, 'setosa'), Text(1, 0, 'versicolor'), Text(2, 0, 'virginica')])

# %%
counts = np.bincount(y_testing)
positions = np.arange(3)

plt.bar(positions, counts)
plt.xticks(positions, data.target_names)
# Out:
# ([<matplotlib.axis.XTick at 0x1363db2e990>,
# ...
#  [Text(0, 0, 'setosa'), Text(1, 0, 'versicolor'), Text(2, 0, 'virginica')])

# %%
split = StratifiedShuffleSplit(n_splits=1, test_size=0.2)

for train_idx, test_idx in split.split(X, y):
    X_train, X_testing = X[train_idx], X[test_idx]
    y_train, y_testing = y[train_idx], y[test_idx]
